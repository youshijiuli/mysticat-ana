# %%
#  水球图 

from pyecharts import options as opts
from pyecharts.charts import Liquid

c = (
    Liquid()
    .add("lq", [0.6, 0.7])  #  0.6 表示数字 0.7表示水的淹没范围 
    .set_global_opts(title_opts=opts.TitleOpts(title="Liquid-基本示例"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="e54a586d729d412db8873336ebc1f6a7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_e54a586d729d412db8873336ebc1f6a7 = echarts.init(
#                     document.getElementById('e54a586d729d412db8873336ebc1f6a7'), 'white', {renderer: 'canvas'});
#                 var option_e54a586d729d412db8873336ebc1f6a7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": true,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Liquid-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_e54a586d729d412db8873336ebc1f6a7.setOption(option_e54a586d729d412db8873336ebc1f6a7);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid

c = (
    Liquid()
    .add("lq", [0.3, 0.7], is_outline_show=False, shape='roundRect')
    .set_global_opts(title_opts=opts.TitleOpts(title="Liquid-Shape-arrow"))
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="bf3a7e226f7b4305a8a6cf280feb53b3" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_bf3a7e226f7b4305a8a6cf280feb53b3 = echarts.init(
#                     document.getElementById('bf3a7e226f7b4305a8a6cf280feb53b3'), 'white', {renderer: 'canvas'});
#                 var option_bf3a7e226f7b4305a8a6cf280feb53b3 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.3,
#                 0.7
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "roundRect",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": false,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Liquid-Shape-arrow",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_bf3a7e226f7b4305a8a6cf280feb53b3.setOption(option_bf3a7e226f7b4305a8a6cf280feb53b3);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Liquid

c = (
    Liquid()
    .add("lq", [0.6, 0.6], is_outline_show=False)
    .set_global_opts(title_opts=opts.TitleOpts(title="Liquid-无边框"))
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'echarts-liquidfill':'https://assets.pyecharts.org/assets/echarts-liquidfill.min'
#         }
#     });
# </script>
#
#         <div id="a420f5562f4f4c3ebc4d484468b41cd6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-liquidfill'], function(echarts) {
#                 var chart_a420f5562f4f4c3ebc4d484468b41cd6 = echarts.init(
#                     document.getElementById('a420f5562f4f4c3ebc4d484468b41cd6'), 'white', {renderer: 'canvas'});
#                 var option_a420f5562f4f4c3ebc4d484468b41cd6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "liquidFill",
#             "name": "lq",
#             "data": [
#                 0.6,
#                 0.6
#             ],
#             "waveAnimation": true,
#             "animationDuration": 2000,
#             "animationDurationUpdate": 1000,
#             "color": [
#                 "#294D99",
#                 "#156ACF",
#                 "#1598ED",
#                 "#45BDFF"
#             ],
#             "shape": "circle",
#             "backgroundStyle": {},
#             "outline": {
#                 "show": false,
#                 "borderDistance": 8
#             },
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8,
#                 "fontSize": 50
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Liquid-\u65e0\u8fb9\u6846",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a420f5562f4f4c3ebc4d484468b41cd6.setOption(option_a420f5562f4f4c3ebc4d484468b41cd6);
#         });
#     </script>

# %%
#  漏斗图 

from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker

c = (
    Funnel()
    .add("商品", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-基本示例"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="3cae3379a6a74c429fbab88b3c809579" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_3cae3379a6a74c429fbab88b3c809579 = echarts.init(
#                     document.getElementById('3cae3379a6a74c429fbab88b3c809579'), 'white', {renderer: 'canvas'});
#                 var option_3cae3379a6a74c429fbab88b3c809579 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u53ef\u4e50",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u96ea\u78a7",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u6a59\u6c41",
#                     "value": 83
#                 },
#                 {
#                     "name": "\u7eff\u8336",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u5976\u8336",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u767e\u5a01",
#                     "value": 59
#                 },
#                 {
#                     "name": "\u9752\u5c9b",
#                     "value": 65
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u7eff\u8336",
#                 "\u5976\u8336",
#                 "\u96ea\u78a7",
#                 "\u6a59\u6c41",
#                 "\u53ef\u4e50",
#                 "\u9752\u5c9b",
#                 "\u767e\u5a01"
#             ],
#             "selected": {
#                 "\u53ef\u4e50": true,
#                 "\u96ea\u78a7": true,
#                 "\u6a59\u6c41": true,
#                 "\u7eff\u8336": true,
#                 "\u5976\u8336": true,
#                 "\u767e\u5a01": true,
#                 "\u9752\u5c9b": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Funnel-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_3cae3379a6a74c429fbab88b3c809579.setOption(option_3cae3379a6a74c429fbab88b3c809579);
#         });
#     </script>

# %%
# Funnel - Funnel_label_inside

from pyecharts import options as opts
from pyecharts.charts import Funnel
from pyecharts.faker import Faker


c = (
    Funnel()
    .add(
        "商品",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        label_opts=opts.LabelOpts(position="inside"),
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Funnel-Label（inside)"))
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9f1c1d3f2b4d407d9d32845436039ea1" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9f1c1d3f2b4d407d9d32845436039ea1 = echarts.init(
#                     document.getElementById('9f1c1d3f2b4d407d9d32845436039ea1'), 'white', {renderer: 'canvas'});
#                 var option_9f1c1d3f2b4d407d9d32845436039ea1 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "funnel",
#             "name": "\u5546\u54c1",
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 129
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 73
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 37
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 43
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 104
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 52
#                 }
#             ],
#             "sort": "descending",
#             "gap": 0,
#             "label": {
#                 "show": true,
#                 "position": "inside",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u897f\u74dc",
#                 "\u8292\u679c",
#                 "\u67e0\u6aac",
#                 "\u8349\u8393",
#                 "\u8f66\u5398\u5b50",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8"
#             ],
#             "selected": {
#                 "\u8349\u8393": true,
#                 "\u8292\u679c": true,
#                 "\u8461\u8404": true,
#                 "\u96ea\u68a8": true,
#                 "\u897f\u74dc": true,
#                 "\u67e0\u6aac": true,
#                 "\u8f66\u5398\u5b50": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Funnel-Label\uff08inside)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9f1c1d3f2b4d407d9d32845436039ea1.setOption(option_9f1c1d3f2b4d407d9d32845436039ea1);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge

c = (
    Gauge()
    .add("ddd", [("完成率", 6.6)],
         end_angle = -45,
         detail_label_opts = opts.GaugeDetailOpts(
                                                  formatter="{value}%",
                                                  border_color = 'red',
                                                  border_width = 1,
                                                  font_size = 30,
                                                  offset_center= [0, "40%"]
                                                 ),
        )
    .set_global_opts(title_opts=opts.TitleOpts(title="Gauge-基本示例"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="36fcb8d1278e4a9ba8701b4de783d9b7" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_36fcb8d1278e4a9ba8701b4de783d9b7 = echarts.init(
#                     document.getElementById('36fcb8d1278e4a9ba8701b4de783d9b7'), 'white', {renderer: 'canvas'});
#                 var option_36fcb8d1278e4a9ba8701b4de783d9b7 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "color": "#333",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "backgroundColor": "transparent",
#                 "borderColor": "transparent",
#                 "borderWidth": 0,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 1,
#                 "borderColor": "red",
#                 "offsetCenter": [
#                     0,
#                     "40%"
#                 ],
#                 "formatter": "{value}%",
#                 "color": "auto",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 30,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "name": "ddd",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 10,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 6.6
#                 }
#             ],
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "ddd"
#             ],
#             "selected": {
#                 "ddd": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Gauge-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_36fcb8d1278e4a9ba8701b4de783d9b7.setOption(option_36fcb8d1278e4a9ba8701b4de783d9b7);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Gauge

c = (
    Gauge()
    .add(
        "业务指标",
        [("完成率", 55.5)],
        split_number= 5,  # 分割段数 
        axisline_opts=opts.AxisLineOpts(
            linestyle_opts=opts.LineStyleOpts(
                color=[(0.3, "#67e0e3"), (0.7, "#37a2da"), (1, "#fd666d")], width=30
            )
        ),
                 detail_label_opts = opts.GaugeDetailOpts(
                                                  formatter="{value}%",
                                                  border_color = 'red',
                                                  border_width = 1,
                                                  font_size = 30,
                                                  offset_center= [0, "40%"]
                                                 )
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Gauge-不同颜色"),
        legend_opts=opts.LegendOpts(is_show=False),
    )
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a8829f466ce2434ca92c58eb1830e133" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a8829f466ce2434ca92c58eb1830e133 = echarts.init(
#                     document.getElementById('a8829f466ce2434ca92c58eb1830e133'), 'white', {renderer: 'canvas'});
#                 var option_a8829f466ce2434ca92c58eb1830e133 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "gauge",
#             "title": {
#                 "show": true,
#                 "offsetCenter": [
#                     0,
#                     "-40%"
#                 ],
#                 "color": "#333",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 15,
#                 "backgroundColor": "transparent",
#                 "borderColor": "transparent",
#                 "borderWidth": 0,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "detail": {
#                 "show": true,
#                 "backgroundColor": "transparent",
#                 "borderWidth": 1,
#                 "borderColor": "red",
#                 "offsetCenter": [
#                     0,
#                     "40%"
#                 ],
#                 "formatter": "{value}%",
#                 "color": "auto",
#                 "fontStyle": "normal",
#                 "fontWeight": "normal",
#                 "fontFamily": "sans-serif",
#                 "fontSize": 30,
#                 "borderRadius": 0,
#                 "padding": 0,
#                 "shadowColor": "transparent",
#                 "shadowBlur": 0,
#                 "shadowOffsetX": 0,
#                 "shadowOffsetY": 0
#             },
#             "name": "\u4e1a\u52a1\u6307\u6807",
#             "min": 0,
#             "max": 100,
#             "splitNumber": 5,
#             "radius": "75%",
#             "startAngle": 225,
#             "endAngle": -45,
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u5b8c\u6210\u7387",
#                     "value": 55.5
#                 }
#             ],
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 30,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid",
#                     "color": [
#                         [
#                             0.3,
#                             "#67e0e3"
#                         ],
#                         [
#                             0.7,
#                             "#37a2da"
#                         ],
#                         [
#                             1,
#                             "#fd666d"
#                         ]
#                     ]
#                 }
#             },
#             "pointer": {
#                 "show": true,
#                 "length": "80%",
#                 "width": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e1a\u52a1\u6307\u6807"
#             ],
#             "selected": {
#                 "\u4e1a\u52a1\u6307\u6807": true
#             },
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Gauge-\u4e0d\u540c\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a8829f466ce2434ca92c58eb1830e133.setOption(option_a8829f466ce2434ca92c58eb1830e133);
#         });
#     </script>

# %%
# 日历图

import datetime
import random

from pyecharts import options as opts
from pyecharts.charts import Calendar


begin = datetime.date(2017, 1, 1)
end = datetime.date(2017, 12, 31)
data = [
    [str(begin + datetime.timedelta(days=i)), random.randint(1000, 25000)]
    for i in range((end - begin).days + 1)
]

c = (
    Calendar()
    .add("", data, calendar_opts=opts.CalendarOpts(range_="2017"))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Calendar-2017年微信步数情况"),
        visualmap_opts=opts.VisualMapOpts(
            max_=20000,
            min_=500,
            orient="horizontal",
            is_piecewise=True,  #  # 是否为分段型 
            pos_top="230px",
            pos_left="100px",
        ),
    )
    .render_notebook()
)

print(data)

c
# Out:
# [['2017-01-01', 9225], ['2017-01-02', 17428], ['2017-01-03', 14104], ['2017-01-04', 4744], ['2017-01-05', 23742], ['2017-01-06', 8183], ['2017-01-07', 16891], ['2017-01-08', 22947], ['2017-01-09', 14807], ['2017-01-10', 3185], ['2017-01-11', 5493], ['2017-01-12', 9882], ['2017-01-13', 6718], ['2017-01-14', 8990], ['2017-01-15', 22456], ['2017-01-16', 10276], ['2017-01-17', 17526], ['2017-01-18', 24815], ['2017-01-19', 4190], ['2017-01-20', 15603], ['2017-01-21', 19291], ['2017-01-22', 14391], ['2017-01-23', 17568], ['2017-01-24', 5477], ['2017-01-25', 4503], ['2017-01-26', 18305], ['2017-01-27', 8208], ['2017-01-28', 12250], ['2017-01-29', 9232], ['2017-01-30', 13940], ['2017-01-31', 24239], ['2017-02-01', 3097], ['2017-02-02', 18676], ['2017-02-03', 7237], ['2017-02-04', 10013], ['2017-02-05', 15214], ['2017-02-06', 12068], ['2017-02-07', 13443], ['2017-02-08', 3842], ['2017-02-09', 18798], ['2017-02-10', 1878], ['2017-02-11', 17674], ['2017-02-12', 4475], ['2017-02-13', 12050], ['2017-02-14', 4980], ['2017-02-15', 4101], ['2017-02-16', 10619], ['2017-02-17', 5536], ['2017-02-18', 2265], ['2017-02-19', 23396], ['2017-02-20', 2121], ['2017-02-21', 13170], ['2017-02-22', 5446], ['2017-02-23', 1196], ['2017-02-24', 17417], ['2017-02-25', 6111], ['2017-02-26', 9428], ['2017-02-27', 24561], ['2017-02-28', 4732], ['2017-03-01', 22326], ['2017-03-02', 19601], ['2017-03-03', 21873], ['2017-03-04', 1330], ['2017-03-05', 5781], ['2017-03-06', 24601], ['2017-03-07', 10543], ['2017-03-08', 7846], ['2017-03-09', 7904], ['2017-03-10', 5712], ['2017-03-11', 12763], ['2017-03-12', 9513], ['2017-03-13', 23933], ['2017-03-14', 14046], ['2017-03-15', 11308], ['2017-03-16', 2399], ['2017-03-17', 6380], ['2017-03-18', 15685], ['2017-03-19', 6321], ['2017-03-20', 23458], ['2017-03-21', 3698], ['2017-03-22', 17736], ['2017-03-23', 3122], ['2017-03-24', 9413], ['2017-03-25', 3263], ['2017-03-26', 6984], ['2017-03-27', 4724], ['2017-03-28', 2760], ['2017-03-29', 21272], ['2017-03-30', 18214], ['2017-03-31', 20319], ['2017-04-01', 20647], ['2017-04-02', 15385], ['2017-04-03', 4595], ['2017-04-04', 22323], ['2017-04-05', 4744], ['2017-04-06', 18254], ['2017-04-07', 3165], ['2017-04-08', 6459], ['2017-04-09', 9944], ['2017-04-10', 12059], ['2017-04-11', 22951], ['2017-04-12', 18754], ['2017-04-13', 17236], ['2017-04-14', 3331], ['2017-04-15', 5194], ['2017-04-16', 7209], ['2017-04-17', 21351], ['2017-04-18', 10220], ['2017-04-19', 20363], ['2017-04-20', 7863], ['2017-04-21', 16637], ['2017-04-22', 2242], ['2017-04-23', 21543], ['2017-04-24', 16300], ['2017-04-25', 1947], ['2017-04-26', 10455], ['2017-04-27', 14707], ['2017-04-28', 7379], ['2017-04-29', 17453], ['2017-04-30', 1063], ['2017-05-01', 3129], ['2017-05-02', 3290], ['2017-05-03', 22596], ['2017-05-04', 23578], ['2017-05-05', 7251], ['2017-05-06', 3464], ['2017-05-07', 1362], ['2017-05-08', 7058], ['2017-05-09', 23852], ['2017-05-10', 12204], ['2017-05-11', 9448], ['2017-05-12', 13514], ['2017-05-13', 16251], ['2017-05-14', 1613], ['2017-05-15', 24842], ['2017-05-16', 21579], ['2017-05-17', 18202], ['2017-05-18', 22678], ['2017-05-19', 15454], ['2017-05-20', 24778], ['2017-05-21', 7026], ['2017-05-22', 15491], ['2017-05-23', 4803], ['2017-05-24', 6317], ['2017-05-25', 1918], ['2017-05-26', 20214], ['2017-05-27', 13994], ['2017-05-28', 13048], ['2017-05-29', 16758], ['2017-05-30', 9328], ['2017-05-31', 10386], ['2017-06-01', 6267], ['2017-06-02', 6747], ['2017-06-03', 5231], ['2017-06-04', 6539], ['2017-06-05', 17366], ['2017-06-06', 2085], ['2017-06-07', 9845], ['2017-06-08', 11141], ['2017-06-09', 10705], ['2017-06-10', 18687], ['2017-06-11', 21436], ['2017-06-12', 4504], ['2017-06-13', 14785], ['2017-06-14', 7054], ['2017-06-15', 8211], ['2017-06-16', 20533], ['2017-06-17', 20744], ['2017-06-18', 20977], ['2017-06-19', 8616], ['2017-06-20', 23685], ['2017-06-21', 6604], ['2017-06-22', 3241], ['2017-06-23', 1374], ['2017-06-24', 9831], ['2017-06-25', 3082], ['2017-06-26', 16033], ['2017-06-27' ...
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5e538143593e430eacf58932fa9ab6d6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5e538143593e430eacf58932fa9ab6d6 = echarts.init(
#                     document.getElementById('5e538143593e430eacf58932fa9ab6d6'), 'white', {renderer: 'canvas'});
#                 var option_5e538143593e430eacf58932fa9ab6d6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "coordinateSystem": "calendar",
#             "data": [
#                 [
#                     "2017-01-01",
#                     9225
#                 ],
#                 [
#                     "2017-01-02",
#                     17428
#                 ],
#                 [
#                     "2017-01-03",
#                     14104
#                 ],
#                 [
#                     "2017-01-04",
#                     4744
#                 ],
#                 [
#                     "2017-01-05",
#                     23742
#                 ],
#                 [
#                     "2017-01-06",
#                     8183
#                 ],
#                 [
#                     "2017-01-07",
#                     16891
#                 ],
#                 [
#                     "2017-01-08",
#                     22947
#                 ],
#                 [
#                     "2017-01-09",
#                     14807
#                 ],
#                 [
#                     "2017-01-10",
#                     3185
#                 ],
#                 [
#                     "2017-01-11",
#                     5493
#                 ],
#                 [
#                     "2017-01-12",
#                     9882
#                 ],
#                 [
#                     "2017-01-13",
#                     6718
#                 ],
#                 [
#                     "2017-01-14",
#                     8990
#                 ],
#                 [
#                     "2017-01-15",
#                     22456
#                 ],
#                 [
#                     "2017-01-16",
#                     10276
#                 ],
#                 [
#                     "2017-01-17",
#                     17526
#                 ],
#                 [
#                     "2017-01-18",
#                     24815
#                 ],
#                 [
#                     "2017-01-19",
#                     4190
#                 ],
#                 [
#                     "2017-01-20",
#                     15603
#                 ],
#                 [
#                     "2017-01-21",
#                     19291
#                 ],
#                 [
#                     "2017-01-22",
#                     14391
#                 ],
#                 [
#                     "2017-01-23",
#                     17568
#                 ],
#                 [
#                     "2017-01-24",
#                     5477
#                 ],
#                 [
#                     "2017-01-25",
#                     4503
#                 ],
#                 [
#                     "2017-01-26",
#                     18305
#                 ],
#                 [
#                     "2017-01-27",
#                     8208
#                 ],
#                 [
#                     "2017-01-28",
#                     12250
#                 ],
#                 [
#                     "2017-01-29",
#                     9232
#                 ],
#                 [
#                     "2017-01-30",
#                     13940
#                 ],
#                 [
#                     "2017-01-31",
#                     24239
#                 ],
#                 [
#                     "2017-02-01",
#                     3097
#                 ],
#                 [
#                     "2017-02-02",
#                     18676
#                 ],
#                 [
#                     "2017-02-03",
#                     7237
#                 ],
#                 [
#                     "2017-02-04",
#                     10013
#                 ],
#                 [
#                     "2017-02-05",
#                     15214
#                 ],
#                 [
#                     "2017-02-06",
#                     12068
#                 ],
#                 [
#                     "2017-02-07",
#                     13443
#                 ],
#                 [
#                     "2017-02-08",
#                     3842
#                 ],
#                 [
#                     "2017-02-09",
#                     18798
#                 ],
#                 [
#                     "2017-02-10",
#                     1878
#                 ],
#                 [
#                     "2017-02-11",
#                     17674
#                 ],
#                 [
#                     "2017-02-12",
#                     4475
#                 ],
#                 [
#                     "2017-02-13",
#                     12050
#                 ],
#                 [
#                     "2017-02-14",
#                     4980
#                 ],
#                 [
#                     "2017-02-15",
#                     4101
#                 ],
#                 [
#                     "2017-02-16",
#                     10619
#                 ],
#                 [
#                     "2017-02-17",
#                     5536
#                 ],
#                 [
#                     "2017-02-18",
#                     2265
#                 ],
#                 [
#                     "2017-02-19",
#                     23396
#                 ],
#                 [
#                     "2017-02-20",
#                     2121
#                 ],
#                 [
#                     "2017-02-21",
#                     13170
#                 ],
#                 [
#                     "2017-02-22",
#                     5446
#                 ],
#                 [
#                     "2017-02-23",
#                     1196
#                 ],
#                 [
#                     "2017-02-24",
#                     17417
#                 ],
#                 [
#                     "2017-02-25",
#                     6111
#                 ],
#                 [
#                     "2017-02-26",
#                     9428
#                 ],
#                 [
#                     "2017-02-27",
#                     24561
#                 ],
#                 [
#                     "2017-02-28",
#                     4732
#                 ],
#                 [
#                     "2017-03-01",
#                     22326
#                 ],
#                 [
#                     "2017-03-02",
#                     19601
#                 ],
#                 [
#                     "2017-03-03",
#                     21873
#                 ],
#                 [
#                     "2017-03-04",
#                     1330
#                 ],
#                 [
#                     "2017-03-05",
#                     5781
#                 ],
#                 [
#                     "2017-03-06",
#                     24601
#                 ],
#                 [
#                     "2017-03-07",
#                     10543
#                 ],
#                 [
#                     "2017-03-08",
#                     7846
#                 ],
#                 [
#                     "2017-03-09",
#                     7904
#                 ],
#                 [

# %%
# 饼图

from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    .add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-基本示例"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .render_notebook()
)


print([list(z) for z in zip(Faker.choose(), Faker.values())])

c
# Out:
# [['衬衫', 118], ['毛衣', 109], ['领带', 70], ['裤子', 76], ['风衣', 81], ['高跟鞋', 80], ['袜子', 64]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="a172790fea90449e84108037c7e1ab41" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_a172790fea90449e84108037c7e1ab41 = echarts.init(
#                     document.getElementById('a172790fea90449e84108037c7e1ab41'), 'white', {renderer: 'canvas'});
#                 var option_a172790fea90449e84108037c7e1ab41 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 30
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 77
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 32
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 47
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 70
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 50
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a172790fea90449e84108037c7e1ab41.setOption(option_a172790fea90449e84108037c7e1ab41);
#         });
#     </script>

# %%
#  设置饼图颜色

from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    .add("", [list(z) for z in zip(Faker.choose(), Faker.values())])
    .set_colors(["blue", "green", "yellow", "red", "pink", "orange", "purple"])
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-设置颜色"))
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c4ddc37e1aec44c3911fe37067b784ad" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c4ddc37e1aec44c3911fe37067b784ad = echarts.init(
#                     document.getElementById('c4ddc37e1aec44c3911fe37067b784ad'), 'white', {renderer: 'canvas'});
#                 var option_c4ddc37e1aec44c3911fe37067b784ad = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "blue",
#         "green",
#         "yellow",
#         "red",
#         "pink",
#         "orange",
#         "purple"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 89
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 48
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u8bbe\u7f6e\u989c\u8272",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_c4ddc37e1aec44c3911fe37067b784ad.setOption(option_c4ddc37e1aec44c3911fe37067b784ad);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker

c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(Faker.choose(), Faker.values())],
        radius=["40%", "75%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Pie-Radius"),
        legend_opts=opts.LegendOpts(orient="vertical", pos_top="15%", pos_left="2%"),
    )
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="b993045adcb6443ab624694fb90dc091" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_b993045adcb6443ab624694fb90dc091 = echarts.init(
#                     document.getElementById('b993045adcb6443ab624694fb90dc091'), 'white', {renderer: 'canvas'});
#                 var option_b993045adcb6443ab624694fb90dc091 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u54c8\u58eb\u5947",
#                     "value": 128
#                 },
#                 {
#                     "name": "\u8428\u6469\u8036",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u6cf0\u8fea",
#                     "value": 65
#                 },
#                 {
#                     "name": "\u91d1\u6bdb",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u7267\u7f8a\u72ac",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u5409\u5a03\u5a03",
#                     "value": 88
#                 },
#                 {
#                     "name": "\u67ef\u57fa",
#                     "value": 127
#                 }
#             ],
#             "radius": [
#                 "40%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a03\u5a03",
#                 "\u67ef\u57fa"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-Radius",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b993045adcb6443ab624694fb90dc091.setOption(option_b993045adcb6443ab624694fb90dc091);
#         });
#     </script>

# %%
# 定制饼图 
import pyecharts.options as opts
from pyecharts.charts import Pie


x_data = ["直接访问", "邮件营销", "联盟广告", "视频广告", "搜索引擎"]
y_data = [335, 310, 274, 235, 400]
data_pair = [list(z) for z in zip(x_data, y_data)]
data_pair.sort(key=lambda x: x[1])  # 根据 列表的死一个索引进行排序 

c =(
    Pie(init_opts=opts.InitOpts(width="800px", height="400px", bg_color="#2c343c"))
    .add(
        series_name="访问来源",
        data_pair=data_pair,
        rosetype="radius",
        radius="55%",
        center=["50%", "50%"],
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(
            title="Customized Pie",
            pos_left="center",
            pos_top="20",
            title_textstyle_opts=opts.TextStyleOpts(color="yellow"), #  #fff
        ),
        legend_opts=opts.LegendOpts(is_show=False),
    )
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/> {b}: {c} ({d}%)"  # {a}：系列名。# {b}：数据名。# {c}：数据值。
        ),
        label_opts=opts.LabelOpts(color="white"), # rgba(255, 255, 255, 0.3)  grey
    )
    .render_notebook()
    
)
print(data_pair)


c
# Out:
# [['视频广告', 235], ['联盟广告', 274], ['邮件营销', 310], ['直接访问', 335], ['搜索引擎', 400]]
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="fa3937defedd4590bea79143c45a70f2" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_fa3937defedd4590bea79143c45a70f2 = echarts.init(
#                     document.getElementById('fa3937defedd4590bea79143c45a70f2'), 'white', {renderer: 'canvas'});
#                 var option_fa3937defedd4590bea79143c45a70f2 = {
#     "backgroundColor": "#2c343c",
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u8bbf\u95ee\u6765\u6e90",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u89c6\u9891\u5e7f\u544a",
#                     "value": 235
#                 },
#                 {
#                     "name": "\u8054\u76df\u5e7f\u544a",
#                     "value": 274
#                 },
#                 {
#                     "name": "\u90ae\u4ef6\u8425\u9500",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u76f4\u63a5\u8bbf\u95ee",
#                     "value": 335
#                 },
#                 {
#                     "name": "\u641c\u7d22\u5f15\u64ce",
#                     "value": 400
#                 }
#             ],
#             "radius": "55%",
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "color": "white",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/> {b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u89c6\u9891\u5e7f\u544a",
#                 "\u8054\u76df\u5e7f\u544a",
#                 "\u90ae\u4ef6\u8425\u9500",
#                 "\u76f4\u63a5\u8bbf\u95ee",
#                 "\u641c\u7d22\u5f15\u64ce"
#             ],
#             "selected": {},
#             "show": false,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Customized Pie",
#             "left": "center",
#             "top": "20",
#             "padding": 5,
#             "itemGap": 10,
#             "textStyle": {
#                 "color": "yellow"
#             }
#         }
#     ]
# };
#                 chart_fa3937defedd4590bea79143c45a70f2.setOption(option_fa3937defedd4590bea79143c45a70f2);
#         });
#     </script>

# %%
import pyecharts.options as opts
from pyecharts.charts import Pie



x_data = ["直接访问", "邮件营销", "联盟广告", "视频广告", "搜索引擎"]
y_data = [335, 310, 234, 135, 1548]

c = (
    Pie(init_opts=opts.InitOpts(width="800px", height="400px"))
    .add(
        series_name="访问来源",
        data_pair=[list(z) for z in zip(x_data, y_data)],
        radius=["50%", "70%"],  #  内半径和外半径 
        label_opts=opts.LabelOpts(is_show=False, position="center"),
    )
    .set_global_opts(legend_opts=opts.LegendOpts(pos_left="legft", orient="vertical"))
    .set_series_opts(
        tooltip_opts=opts.TooltipOpts(
            trigger="item", formatter="{a} <br/>{b}: {c} ({d}%)"
        ),
        # label_opts=opts.LabelOpts(formatter="{b}: {c}")
    )
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d35b070667b343469c0db02ec7ee409d" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d35b070667b343469c0db02ec7ee409d = echarts.init(
#                     document.getElementById('d35b070667b343469c0db02ec7ee409d'), 'white', {renderer: 'canvas'});
#                 var option_d35b070667b343469c0db02ec7ee409d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "name": "\u8bbf\u95ee\u6765\u6e90",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u76f4\u63a5\u8bbf\u95ee",
#                     "value": 335
#                 },
#                 {
#                     "name": "\u90ae\u4ef6\u8425\u9500",
#                     "value": 310
#                 },
#                 {
#                     "name": "\u8054\u76df\u5e7f\u544a",
#                     "value": 234
#                 },
#                 {
#                     "name": "\u89c6\u9891\u5e7f\u544a",
#                     "value": 135
#                 },
#                 {
#                     "name": "\u641c\u7d22\u5f15\u64ce",
#                     "value": 1548
#                 }
#             ],
#             "radius": [
#                 "50%",
#                 "70%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": false,
#                 "position": "center",
#                 "margin": 8
#             },
#             "tooltip": {
#                 "show": true,
#                 "trigger": "item",
#                 "triggerOn": "mousemove|click",
#                 "axisPointer": {
#                     "type": "line"
#                 },
#                 "showContent": true,
#                 "alwaysShowContent": false,
#                 "showDelay": 0,
#                 "hideDelay": 100,
#                 "formatter": "{a} <br/>{b}: {c} ({d}%)",
#                 "textStyle": {
#                     "fontSize": 14
#                 },
#                 "borderWidth": 0,
#                 "padding": 5
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u76f4\u63a5\u8bbf\u95ee",
#                 "\u90ae\u4ef6\u8425\u9500",
#                 "\u8054\u76df\u5e7f\u544a",
#                 "\u89c6\u9891\u5e7f\u544a",
#                 "\u641c\u7d22\u5f15\u64ce"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "legft",
#             "orient": "vertical",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_d35b070667b343469c0db02ec7ee409d.setOption(option_d35b070667b343469c0db02ec7ee409d);
#         });
#     </script>

# %%
# Pie_rosetype 玫瑰图 

from pyecharts import options as opts
from pyecharts.charts import Pie
from pyecharts.faker import Faker


v = Faker.choose()
c = (
    Pie()
    .add(
        "",
        [list(z) for z in zip(v, Faker.values())],
        radius=["30%", "75%"],
        center=["25%", "50%"],
        rosetype="radius",
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add(
        "",
        [list(z) for z in zip(v, Faker.values())],
        radius=["30%", "75%"],
        center=["75%", "50%"],
        rosetype="area",
    )
    .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="bf3ecf2ccb004ca28a6af2663fc1e8e5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_bf3ecf2ccb004ca28a6af2663fc1e8e5 = echarts.init(
#                     document.getElementById('bf3ecf2ccb004ca28a6af2663fc1e8e5'), 'white', {renderer: 'canvas'});
#                 var option_bf3ecf2ccb004ca28a6af2663fc1e8e5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 36
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 113
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 29
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 66
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 145
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "25%",
#                 "50%"
#             ],
#             "roseType": "radius",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "pie",
#             "clockwise": true,
#             "data": [
#                 {
#                     "name": "\u8349\u8393",
#                     "value": 139
#                 },
#                 {
#                     "name": "\u8292\u679c",
#                     "value": 28
#                 },
#                 {
#                     "name": "\u8461\u8404",
#                     "value": 97
#                 },
#                 {
#                     "name": "\u96ea\u68a8",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u897f\u74dc",
#                     "value": 118
#                 },
#                 {
#                     "name": "\u67e0\u6aac",
#                     "value": 34
#                 },
#                 {
#                     "name": "\u8f66\u5398\u5b50",
#                     "value": 92
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "75%"
#             ],
#             "center": [
#                 "75%",
#                 "50%"
#             ],
#             "roseType": "area",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8349\u8393",
#                 "\u8292\u679c",
#                 "\u8461\u8404",
#                 "\u96ea\u68a8",
#                 "\u897f\u74dc",
#                 "\u67e0\u6aac",
#                 "\u8f66\u5398\u5b50"
#             ],
#             "selected": {},
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Pie-\u73ab\u7470\u56fe\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_bf3ecf2ccb004ca28a6af2663fc1e8e5.setOption(option_bf3ecf2ccb004ca28a6af2663fc1e8e5);
#         });
#     </script>

# %%
# Effectscatter - Effectscatter_base
from pyecharts import options as opts
from pyecharts.charts import EffectScatter
from pyecharts.faker import Faker

c = (
    EffectScatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="EffectScatter-基本示例"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="38752fd7bbb944ccaa3afed6c4a84690" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_38752fd7bbb944ccaa3afed6c4a84690 = echarts.init(
#                     document.getElementById('38752fd7bbb944ccaa3afed6c4a84690'), 'white', {renderer: 'canvas'});
#                 var option_38752fd7bbb944ccaa3afed6c4a84690 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     75
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     100
#                 ],
#                 [
#                     "\u8001\u864e",
#                     130
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     113
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     142
#                 ],
#                 [
#                     "\u718a\u732b",
#                     34
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     75
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "EffectScatter-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_38752fd7bbb944ccaa3afed6c4a84690.setOption(option_38752fd7bbb944ccaa3afed6c4a84690);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import EffectScatter
from pyecharts.faker import Faker


c = (
    EffectScatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("", Faker.values(), symbol='arrow')  # circle line  arrow 
    .set_global_opts(title_opts=opts.TitleOpts(title="EffectScatter-不同Symbol"))
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2e673212f5c447fdb5fc942deb8604f5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2e673212f5c447fdb5fc942deb8604f5 = echarts.init(
#                     document.getElementById('2e673212f5c447fdb5fc942deb8604f5'), 'white', {renderer: 'canvas'});
#                 var option_2e673212f5c447fdb5fc942deb8604f5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "arrow",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     142
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     133
#                 ],
#                 [
#                     "\u8001\u864e",
#                     118
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     85
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     29
#                 ],
#                 [
#                     "\u718a\u732b",
#                     45
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     61
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "EffectScatter-\u4e0d\u540cSymbol",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_2e673212f5c447fdb5fc942deb8604f5.setOption(option_2e673212f5c447fdb5fc942deb8604f5);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import EffectScatter
from pyecharts.faker import Faker

c = (
    EffectScatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="EffectScatter-显示分割线"),
        xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
        yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
    )
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="0beb1605818747f1a616349fab8191aa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_0beb1605818747f1a616349fab8191aa = echarts.init(
#                     document.getElementById('0beb1605818747f1a616349fab8191aa'), 'white', {renderer: 'canvas'});
#                 var option_0beb1605818747f1a616349fab8191aa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     65
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     112
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     48
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     44
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     132
#                 ],
#                 [
#                     "VIVO",
#                     47
#                 ],
#                 [
#                     "OPPO",
#                     29
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "EffectScatter-\u663e\u793a\u5206\u5272\u7ebf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_0beb1605818747f1a616349fab8191aa.setOption(option_0beb1605818747f1a616349fab8191aa);
#         });
#     </script>

# %%
# 箱型图 

from pyecharts import options as opts
from pyecharts.charts import Boxplot

v1 = [
    [850, 740, 900, 1070, 930, 850, 950, 980, 980, 880, 1000, 980],
    [960, 940, 960, 940, 880, 800, 850, 880, 900, 840, 830, 790],
]
v2 = [
    [890, 810, 810, 820, 800, 770, 760, 740, 750, 760, 910, 920],
    [890, 840, 780, 810, 760, 810, 790, 810, 820, 850, 870, 870],
]
c = Boxplot()
c.add_xaxis(["expr1", "expr2"])
c.add_yaxis("A", c.prepare_data(v1))
c.add_yaxis("B", c.prepare_data(v2))
c.set_global_opts(title_opts=opts.TitleOpts(title="BoxPlot-基本示例"))
c.render_notebook()
# c.prepare_data(v1)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ef5694fd9a844c35be9778e01433502d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ef5694fd9a844c35be9778e01433502d = echarts.init(
#                     document.getElementById('ef5694fd9a844c35be9778e01433502d'), 'white', {renderer: 'canvas'});
#                 var option_ef5694fd9a844c35be9778e01433502d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "boxplot",
#             "name": "A",
#             "data": [
#                 [
#                     740,
#                     857.5,
#                     940.0,
#                     980.0,
#                     1070
#                 ],
#                 [
#                     790,
#                     832.5,
#                     880.0,
#                     940.0,
#                     960
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         },
#         {
#             "type": "boxplot",
#             "name": "B",
#             "data": [
#                 [
#                     740,
#                     760.0,
#                     805.0,
#                     872.5,
#                     920
#                 ],
#                 [
#                     760,
#                     795.0,
#                     815.0,
#                     865.0,
#                     890
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "markPoint": {
#                 "label": {
#                     "show": true,
#                     "position": "inside",
#                     "color": "#fff",
#                     "margin": 8
#                 }
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 }
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "A",
#                 "B"
#             ],
#             "selected": {
#                 "A": true,
#                 "B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "expr1",
#                 "expr2"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "BoxPlot-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_ef5694fd9a844c35be9778e01433502d.setOption(option_ef5694fd9a844c35be9778e01433502d);
#         });
#     </script>

# %%
import random

from pyecharts import options as opts
from pyecharts.charts import HeatMap
from pyecharts.faker import Faker

value = [[i, j, random.randint(0, 50)] for i in range(24) for j in range(7)]
c = (
    HeatMap()
    .add_xaxis(Faker.clock)
    .add_yaxis("series0", Faker.week, value)
    .set_global_opts(
        title_opts=opts.TitleOpts(title="HeatMap-基本示例"),
        visualmap_opts=opts.VisualMapOpts(),
    )
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="01c2de1885cc4bfdbcbd568f0e4da126" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_01c2de1885cc4bfdbcbd568f0e4da126 = echarts.init(
#                     document.getElementById('01c2de1885cc4bfdbcbd568f0e4da126'), 'white', {renderer: 'canvas'});
#                 var option_01c2de1885cc4bfdbcbd568f0e4da126 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "series0",
#             "data": [
#                 [
#                     0,
#                     0,
#                     41
#                 ],
#                 [
#                     0,
#                     1,
#                     48
#                 ],
#                 [
#                     0,
#                     2,
#                     30
#                 ],
#                 [
#                     0,
#                     3,
#                     21
#                 ],
#                 [
#                     0,
#                     4,
#                     19
#                 ],
#                 [
#                     0,
#                     5,
#                     23
#                 ],
#                 [
#                     0,
#                     6,
#                     24
#                 ],
#                 [
#                     1,
#                     0,
#                     20
#                 ],
#                 [
#                     1,
#                     1,
#                     14
#                 ],
#                 [
#                     1,
#                     2,
#                     2
#                 ],
#                 [
#                     1,
#                     3,
#                     40
#                 ],
#                 [
#                     1,
#                     4,
#                     47
#                 ],
#                 [
#                     1,
#                     5,
#                     44
#                 ],
#                 [
#                     1,
#                     6,
#                     5
#                 ],
#                 [
#                     2,
#                     0,
#                     32
#                 ],
#                 [
#                     2,
#                     1,
#                     0
#                 ],
#                 [
#                     2,
#                     2,
#                     30
#                 ],
#                 [
#                     2,
#                     3,
#                     36
#                 ],
#                 [
#                     2,
#                     4,
#                     44
#                 ],
#                 [
#                     2,
#                     5,
#                     14
#                 ],
#                 [
#                     2,
#                     6,
#                     14
#                 ],
#                 [
#                     3,
#                     0,
#                     17
#                 ],
#                 [
#                     3,
#                     1,
#                     35
#                 ],
#                 [
#                     3,
#                     2,
#                     2
#                 ],
#                 [
#                     3,
#                     3,
#                     31
#                 ],
#                 [
#                     3,
#                     4,
#                     33
#                 ],
#                 [
#                     3,
#                     5,
#                     37
#                 ],
#                 [
#                     3,
#                     6,
#                     1
#                 ],
#                 [
#                     4,
#                     0,
#                     36
#                 ],
#                 [
#                     4,
#                     1,
#                     39
#                 ],
#                 [
#                     4,
#                     2,
#                     32
#                 ],
#                 [
#                     4,
#                     3,
#                     22
#                 ],
#                 [
#                     4,
#                     4,
#                     49
#                 ],
#                 [
#                     4,
#                     5,
#                     24
#                 ],
#                 [
#                     4,
#                     6,
#                     1
#                 ],
#                 [
#                     5,
#                     0,
#                     3
#                 ],
#                 [
#                     5,
#                     1,
#                     42
#                 ],
#                 [
#                     5,
#                     2,
#                     19
#                 ],
#                 [
#                     5,
#                     3,
#                     19
#                 ],
#                 [
#                     5,
#                     4,
#                     38
#                 ],
#                 [
#                     5,
#                     5,
#                     14
#                 ],
#                 [
#                     5,
#                     6,
#                     42
#                 ],
#                 [
#                     6,
#                     0,
#                     17
#                 ],
#                 [
#                     6,
#                     1,
#                     18
#                 ],
#                 [
#                     6,
#                     2,
#                     41
#                 ],
#                 [
#                     6,
#                     3,
#                     44
#                 ],
#                 [
#                     6,
#                     4,
#                     44
#                 ],
#                 [
#                     6,
#                     5,
#                     27
#                 ],
#                 [
#                     6,
#                     6,
#                     30
#                 ],
#                 [
#                     7,
#                     0,
#                     17
#                 ],
#                 [
#                     7,
#                     1,
#                     32
#                 ],
#                 [
#                     7,
#                     2,
#                     24
#                 ],
#                 [
#                     7,
#                     3,
#                     17
#                 ],
#                 [
#                     7,
#                     4,
#                     48
#                 ],
#                 [
#                     7,
#                     5,
#                     45
#                 ],
#                 [
#                     7,
#                     6,
#                     10
#                 ],
#                 [
#                     8,
#                     0,
#                     16
#                 ],
#                 [
#                     8,
#                     1,
#                     3
#                 ],
#                 [
#                     8,
#                     2,
#                     47
#                 ],
#                 [
#                     8,
#                     3,
#                     32
#                 ],
#                 [
#                     8,
#                     4,
#                     28
#                 ],
#                 [
#                     8,
#                     5,
#                     38
#                 ],
#                 [
#                     8,

# %%
# 象形柱状图
from pyecharts import options as opts
from pyecharts.charts import PictorialBar


location = ["山西", "四川", "西藏", "北京", "上海", "内蒙古", "云南", "黑龙江", "广东", "福建"]
values = [13, 42, 67, 81, 86, 94, 166, 220, 249, 262]

c = (
    PictorialBar()
    .add_xaxis(location)
    .add_yaxis(
        "",
        values,
        label_opts=opts.LabelOpts(is_show=False),
        symbol_size=18,
        symbol_repeat=True,
        is_symbol_clip=True,

    )
    .reversal_axis()
    .set_global_opts(
        title_opts=opts.TitleOpts(title="PictorialBar-各省份人口数量（虚假数据）"),
        xaxis_opts=opts.AxisOpts(is_show=False),
        yaxis_opts=opts.AxisOpts(
            axistick_opts=opts.AxisTickOpts(is_show=False),
            axisline_opts=opts.AxisLineOpts(
                linestyle_opts=opts.LineStyleOpts(opacity=0)
            ),
        ),
    )
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9b04f5bc5f9a49c2b91cff8ec0d9cdcb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9b04f5bc5f9a49c2b91cff8ec0d9cdcb = echarts.init(
#                     document.getElementById('9b04f5bc5f9a49c2b91cff8ec0d9cdcb'), 'white', {renderer: 'canvas'});
#                 var option_9b04f5bc5f9a49c2b91cff8ec0d9cdcb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pictorialBar",
#             "symbolSize": 18,
#             "symbolRepeat": true,
#             "symbolClip": true,
#             "data": [
#                 13,
#                 42,
#                 67,
#                 81,
#                 86,
#                 94,
#                 166,
#                 220,
#                 249,
#                 262
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": false,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLine": {
#                 "show": true,
#                 "onZero": true,
#                 "onZeroAxisIndex": 0,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 0,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "axisTick": {
#                 "show": false,
#                 "alignWithLabel": false,
#                 "inside": false
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c71\u897f",
#                 "\u56db\u5ddd",
#                 "\u897f\u85cf",
#                 "\u5317\u4eac",
#                 "\u4e0a\u6d77",
#                 "\u5185\u8499\u53e4",
#                 "\u4e91\u5357",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u5e7f\u4e1c",
#                 "\u798f\u5efa"
#             ]
#         }
#     ],
#     "title": [
#         {
#             "text": "PictorialBar-\u5404\u7701\u4efd\u4eba\u53e3\u6570\u91cf\uff08\u865a\u5047\u6570\u636e\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_9b04f5bc5f9a49c2b91cff8ec0d9cdcb.setOption(option_9b04f5bc5f9a49c2b91cff8ec0d9cdcb);
#         });
#     </script>

# %%
#  散点图 scatter

from pyecharts import options as opts
from pyecharts.charts import Scatter
from pyecharts.faker import Faker

c = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Scatter-显示分割线"),
        xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
        yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
    )
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="825205ce70b04bf2bbdcf2fa88549377" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_825205ce70b04bf2bbdcf2fa88549377 = echarts.init(
#                     document.getElementById('825205ce70b04bf2bbdcf2fa88549377'), 'white', {renderer: 'canvas'});
#                 var option_825205ce70b04bf2bbdcf2fa88549377 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u6cb3\u9a6c",
#                     126
#                 ],
#                 [
#                     "\u87d2\u86c7",
#                     137
#                 ],
#                 [
#                     "\u8001\u864e",
#                     95
#                 ],
#                 [
#                     "\u5927\u8c61",
#                     54
#                 ],
#                 [
#                     "\u5154\u5b50",
#                     111
#                 ],
#                 [
#                     "\u718a\u732b",
#                     34
#                 ],
#                 [
#                     "\u72ee\u5b50",
#                     57
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6cb3\u9a6c",
#                 "\u87d2\u86c7",
#                 "\u8001\u864e",
#                 "\u5927\u8c61",
#                 "\u5154\u5b50",
#                 "\u718a\u732b",
#                 "\u72ee\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-\u663e\u793a\u5206\u5272\u7ebf",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_825205ce70b04bf2bbdcf2fa88549377.setOption(option_825205ce70b04bf2bbdcf2fa88549377);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter
from pyecharts.faker import Faker

c = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Scatter-VisualMap(Color)"),
        visualmap_opts=opts.VisualMapOpts(max_=150),
    )
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="5e3c109c514245f58dfe4672ff78fbcc" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_5e3c109c514245f58dfe4672ff78fbcc = echarts.init(
#                     document.getElementById('5e3c109c514245f58dfe4672ff78fbcc'), 'white', {renderer: 'canvas'});
#                 var option_5e3c109c514245f58dfe4672ff78fbcc = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5c0f\u7c73",
#                     34
#                 ],
#                 [
#                     "\u4e09\u661f",
#                     94
#                 ],
#                 [
#                     "\u534e\u4e3a",
#                     119
#                 ],
#                 [
#                     "\u82f9\u679c",
#                     59
#                 ],
#                 [
#                     "\u9b45\u65cf",
#                     92
#                 ],
#                 [
#                     "VIVO",
#                     25
#                 ],
#                 [
#                     "OPPO",
#                     99
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u5c0f\u7c73",
#                 "\u4e09\u661f",
#                 "\u534e\u4e3a",
#                 "\u82f9\u679c",
#                 "\u9b45\u65cf",
#                 "VIVO",
#                 "OPPO"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-VisualMap(Color)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 150,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_5e3c109c514245f58dfe4672ff78fbcc.setOption(option_5e3c109c514245f58dfe4672ff78fbcc);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter
from pyecharts.faker import Faker

c = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Scatter-VisualMap(Size)"),
        visualmap_opts=opts.VisualMapOpts(type_="size", max_=150, min_=20),
    )
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="dd48ead04bd6433bb3bb6d97c3cb8c64" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_dd48ead04bd6433bb3bb6d97c3cb8c64 = echarts.init(
#                     document.getElementById('dd48ead04bd6433bb3bb6d97c3cb8c64'), 'white', {renderer: 'canvas'});
#                 var option_dd48ead04bd6433bb3bb6d97c3cb8c64 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     56
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     60
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     65
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     21
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     39
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     129
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     52
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6B",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     104
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     61
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     103
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     50
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     110
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     73
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     140
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u886c\u886b",
#                 "\u6bdb\u8863",
#                 "\u9886\u5e26",
#                 "\u88e4\u5b50",
#                 "\u98ce\u8863",
#                 "\u9ad8\u8ddf\u978b",
#                 "\u889c\u5b50"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Scatter-VisualMap(Size)",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 20,
#         "max": 150,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_dd48ead04bd6433bb3bb6d97c3cb8c64.setOption(option_dd48ead04bd6433bb3bb6d97c3cb8c64);
#         });
#     </script>

# %%
# 层叠多图

import pyecharts.options as opts
from pyecharts.charts import Bar, Line


x_data = ["1月", "2月", "3月", "4月", "5月", "6月",
          "7月", "8月", "9月", "10月", "11月", "12月"]

bar = (
    Bar(init_opts=opts.InitOpts(width="800px", height="400px"))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="蒸发量",
        y_axis=[
            2.0,
            4.9,
            7.0,
            23.2,
            25.6,
            76.7,
            135.6,
            162.2,
            32.6,
            20.0,
            6.4,
            3.3,
        ],
        label_opts=opts.LabelOpts(is_show=False),
    )
    .add_yaxis(
        series_name="降水量",
        y_axis=[
            2.6,
            5.9,
            9.0,
            26.4,
            28.7,
            70.7,
            175.6,
            182.2,
            48.7,
            18.8,
            6.0,
            2.3,
        ],
        label_opts=opts.LabelOpts(is_show=False),
    )
    .extend_axis(
        yaxis=opts.AxisOpts(
            name="温度",
            type_="value",
            min_=0,
            max_=25,
            interval=5,
            axislabel_opts=opts.LabelOpts(formatter="{value} °C"),
        )
    )
    .set_global_opts(
        # 提示框设置
        tooltip_opts=opts.TooltipOpts(
            is_show=True, trigger="axis", axis_pointer_type="cross"
        ),
        xaxis_opts=opts.AxisOpts(
            type_="category",
            axispointer_opts=opts.AxisPointerOpts(
                is_show=True, type_="shadow"),
        ),
        yaxis_opts=opts.AxisOpts(
            name="水量",
            type_="value",
            min_=0,
            max_=250,
            interval=50,
            axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
        ),
    )
)

# 折线图 

line = (
    Line()
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="平均温度",
        yaxis_index=1,# 使用的 y 轴的 index
        y_axis=[2.0, 2.2, 3.3, 4.5, 6.3, 10.2,
                20.3, 23.4, 23.0, 16.5, 12.0, 6.2],
        label_opts=opts.LabelOpts(is_show=True),
    )
)

bar.overlap(line).render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="77ee88fe2fd248f997b0dd6a191e8971" style="width:800px; height:400px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_77ee88fe2fd248f997b0dd6a191e8971 = echarts.init(
#                     document.getElementById('77ee88fe2fd248f997b0dd6a191e8971'), 'white', {renderer: 'canvas'});
#                 var option_77ee88fe2fd248f997b0dd6a191e8971 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u84b8\u53d1\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 2.0,
#                 4.9,
#                 7.0,
#                 23.2,
#                 25.6,
#                 76.7,
#                 135.6,
#                 162.2,
#                 32.6,
#                 20.0,
#                 6.4,
#                 3.3
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u964d\u6c34\u91cf",
#             "legendHoverLink": true,
#             "data": [
#                 2.6,
#                 5.9,
#                 9.0,
#                 26.4,
#                 28.7,
#                 70.7,
#                 175.6,
#                 182.2,
#                 48.7,
#                 18.8,
#                 6.0,
#                 2.3
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u6e29\u5ea6",
#             "connectNulls": false,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "1\u6708",
#                     2.0
#                 ],
#                 [
#                     "2\u6708",
#                     2.2
#                 ],
#                 [
#                     "3\u6708",
#                     3.3
#                 ],
#                 [
#                     "4\u6708",
#                     4.5
#                 ],
#                 [
#                     "5\u6708",
#                     6.3
#                 ],
#                 [
#                     "6\u6708",
#                     10.2
#                 ],
#                 [
#                     "7\u6708",
#                     20.3
#                 ],
#                 [
#                     "8\u6708",
#                     23.4
#                 ],
#                 [
#                     "9\u6708",
#                     23.0
#                 ],
#                 [
#                     "10\u6708",
#                     16.5
#                 ],
#                 [
#                     "11\u6708",
#                     12.0
#                 ],
#                 [
#                     "12\u6708",
#                     6.2
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u84b8\u53d1\u91cf",
#                 "\u964d\u6c34\u91cf",
#                 "\u5e73\u5747\u6e29\u5ea6"
#             ],
#             "selected": {
#                 "\u84b8\u53d1\u91cf": true,
#                 "\u964d\u6c34\u91cf": true,
#                 "\u5e73\u5747\u6e29\u5ea6": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "axis",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "cross"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "type": "category",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisPointer": {
#                 "show": true,
#                 "type": "shadow"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "1\u6708",
#                 "2\u6708",
#                 "3\u6708",
#                 "4\u6708",
#                 "5\u6708",
#                 "6\u6708",
#                 "7\u6708",
#                 "8\u6708",
#                 "9\u6708",
#                 "10\u6708",
#                 "11\u6708",
#                 "12\u6708"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "type": "value",
#             "name": "\u6c34\u91cf",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "interval": 50,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{value} ml"
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "min": 0,
#             "max": 250,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         },
#         {
#             "type": "value",
#             "name": "\u

# %%
#  地理图  geography  

from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

c = (
    Geo()
    .add_schema(maptype="china")  #  pyecharts.datasets.map_filenames.json 
    .add("geo", [list(z) for z in zip(Faker.provinces, Faker.values())]) # ['长春市','吉林市']
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-基本示例")
    )
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="a58fbb7d4e254959a2162f97d6ed5865" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_a58fbb7d4e254959a2162f97d6ed5865 = echarts.init(
#                     document.getElementById('a58fbb7d4e254959a2162f97d6ed5865'), 'white', {renderer: 'canvas'});
#                 var option_a58fbb7d4e254959a2162f97d6ed5865 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         96
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         76
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         76
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         44
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         32
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         92
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Geo-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_a58fbb7d4e254959a2162f97d6ed5865.setOption(option_a58fbb7d4e254959a2162f97d6ed5865);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

c = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "geo",
        [list(z) for z in zip(Faker.provinces, Faker.values())],
        type_='effectScatter',  # heatmap
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-EffectScatter"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="2c785a79ff4e406c9a4f700c2e5ca32a" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_2c785a79ff4e406c9a4f700c2e5ca32a = echarts.init(
#                     document.getElementById('2c785a79ff4e406c9a4f700c2e5ca32a'), 'white', {renderer: 'canvas'});
#                 var option_2c785a79ff4e406c9a4f700c2e5ca32a = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         87
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         22
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         135
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         79
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         54
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         134
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         114
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Geo-EffectScatter",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_2c785a79ff4e406c9a4f700c2e5ca32a.setOption(option_2c785a79ff4e406c9a4f700c2e5ca32a);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

c = (
    Geo()
    .add_schema(maptype="广东")
    .add(
        "geo",
        [list(z) for z in zip(Faker.guangdong_city, Faker.values())],
        type_='heatmap',
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-广东地图")
    )
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="17c6f80494174ee7bee6026f0ce1ec66" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_17c6f80494174ee7bee6026f0ce1ec66 = echarts.init(
#                     document.getElementById('17c6f80494174ee7bee6026f0ce1ec66'), 'white', {renderer: 'canvas'});
#                 var option_17c6f80494174ee7bee6026f0ce1ec66 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "heatmap",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": [
#                         116.68,
#                         23.35,
#                         44
#                     ]
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": [
#                         115.37,
#                         22.78,
#                         142
#                     ]
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": [
#                         116.37,
#                         23.55,
#                         110
#                     ]
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": [
#                         111.98,
#                         21.87,
#                         130
#                     ]
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": [
#                         112.47,
#                         23.05,
#                         134
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": [
#                         113.27,
#                         23.13,
#                         62
#                     ]
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": [
#                         114.42,
#                         23.12,
#                         37
#                     ]
#                 }
#             ],
#             "pointSize": 20,
#             "blurSize": 20,
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Geo-\u5e7f\u4e1c\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "\u5e7f\u4e1c",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_17c6f80494174ee7bee6026f0ce1ec66.setOption(option_17c6f80494174ee7bee6026f0ce1ec66);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

c = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "",
        [("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)],
        type_=ChartType.EFFECT_SCATTER, # scatter, effectScatter, heatmap, lines
        color="yellow",
    )
    .add(
        "geo",
        [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts( 
            symbol=SymbolType.ARROW, symbol_size=6, color="blue"   # ECharts 提供的标记类型包括 'circle', 'rect', 'roundRect', 'triangle', 
    # 'diamond', 'pin', 'arrow', 'none'
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines"))
    .render_notebook()
)
c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="de0d4081bd51448ca5308cf89379f2a6" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_de0d4081bd51448ca5308cf89379f2a6 = echarts.init(
#                     document.getElementById('de0d4081bd51448ca5308cf89379f2a6'), 'white', {renderer: 'canvas'});
#                 var option_de0d4081bd51448ca5308cf89379f2a6 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "yellow",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         77
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         88
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "blue",
#                 "symbol": "arrow",
#                 "symbolSize": 6
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde->\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0.2,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 "geo"
#             ],
#             "selected": {
#                 "": true,
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Geo-Lines",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_de0d4081bd51448ca5308cf89379f2a6.setOption(option_de0d4081bd51448ca5308cf89379f2a6);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.faker import Faker

c = (
    Geo()
    .add_schema(maptype="china")
    .add("geo", [list(z) for z in zip(Faker.provinces, Faker.values())])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(is_piecewise=True),
        title_opts=opts.TitleOpts(title="Geo-VisualMap（分段型）"),
    )
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="1929c0198cd34bafb3f756dbdf7e2c11" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_1929c0198cd34bafb3f756dbdf7e2c11 = echarts.init(
#                     document.getElementById('1929c0198cd34bafb3f756dbdf7e2c11'), 'white', {renderer: 'canvas'});
#                 var option_1929c0198cd34bafb3f756dbdf7e2c11 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": [
#                         113.26653,
#                         23.132191,
#                         121
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         96
#                     ]
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": [
#                         121.473701,
#                         31.230416,
#                         121
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": [
#                         115.909228,
#                         28.675696,
#                         117
#                     ]
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": [
#                         112.98381,
#                         28.112444,
#                         110
#                     ]
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": [
#                         120.152791,
#                         30.267446,
#                         31
#                     ]
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": [
#                         118.763232,
#                         32.061707,
#                         134
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "geo"
#             ],
#             "selected": {
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Geo-VisualMap\uff08\u5206\u6bb5\u578b\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 14,
#         "borderWidth": 0
#     },
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "emphasis": {}
#     }
# };
#                 chart_1929c0198cd34bafb3f756dbdf7e2c11.setOption(option_1929c0198cd34bafb3f756dbdf7e2c11);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.globals import ChartType, SymbolType

c = (
    Geo()
    .add_schema(
        maptype="china",
        itemstyle_opts=opts.ItemStyleOpts(color="#323c48", border_color="red"), #  #111
    )
    .add(
        "",
        [("广州", 55), ("北京", 66), ("杭州", 77), ("重庆", 88)],
        type_=ChartType.EFFECT_SCATTER,
        color="white",
    )
    .add(
        "geo",
        [("广州", "上海"), ("广州", "北京"), ("广州", "杭州"), ("广州", "重庆")],
        type_=ChartType.LINES,
        effect_opts=opts.EffectOpts(
            symbol=SymbolType.ARROW, symbol_size=6, color="blue"
        ),
        linestyle_opts=opts.LineStyleOpts(curve=0.2),
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Geo-Lines-background"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="8c0452923ce34fb6bc3127f2877d6f85" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_8c0452923ce34fb6bc3127f2877d6f85 = echarts.init(
#                     document.getElementById('8c0452923ce34fb6bc3127f2877d6f85'), 'white', {renderer: 'canvas'});
#                 var option_8c0452923ce34fb6bc3127f2877d6f85 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "white",
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "effectScatter",
#             "coordinateSystem": "geo",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde",
#                     "value": [
#                         113.23,
#                         23.16,
#                         55
#                     ]
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": [
#                         116.407526,
#                         39.90403,
#                         66
#                     ]
#                 },
#                 {
#                     "name": "\u676d\u5dde",
#                     "value": [
#                         120.19,
#                         30.26,
#                         77
#                     ]
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": [
#                         106.551556,
#                         29.563009,
#                         88
#                     ]
#                 }
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "lines",
#             "name": "geo",
#             "coordinateSystem": "geo",
#             "zlevel": 3,
#             "progressive": 400,
#             "progressiveThreshold": 3000,
#             "effect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4,
#                 "color": "blue",
#                 "symbol": "arrow",
#                 "symbolSize": 6
#             },
#             "symbol": [
#                 "none",
#                 "arrow"
#             ],
#             "polyline": false,
#             "large": false,
#             "largeThreshold": 2000,
#             "symbolSize": 12,
#             "data": [
#                 {
#                     "name": "\u5e7f\u5dde->\u4e0a\u6d77",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             121.473701,
#                             31.230416
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u5317\u4eac",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             116.407526,
#                             39.90403
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u676d\u5dde",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             120.19,
#                             30.26
#                         ]
#                     ]
#                 },
#                 {
#                     "name": "\u5e7f\u5dde->\u91cd\u5e86",
#                     "coords": [
#                         [
#                             113.23,
#                             23.16
#                         ],
#                         [
#                             106.551556,
#                             29.563009
#                         ]
#                     ]
#                 }
#             ],
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0.2,
#                 "type": "solid"
#             },
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 "geo"
#             ],
#             "selected": {
#                 "": true,
#                 "geo": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "formatter": function (params) {        return params.name + ' : ' + params.value[2];    },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Geo-Lines-background",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "geo": {
#         "map": "china",
#         "roam": true,
#         "aspectScale": 0.75,
#         "nameProperty": "name",
#         "selectedMode": false,
#         "itemStyle": {
#             "color": "#323c48",
#             "borderColor": "red"
#         },
#         "emphasis": {}
#     }
# };
#                 chart_8c0452923ce34fb6bc3127f2877d6f85.setOption(option_8c0452923ce34fb6bc3127f2877d6f85);
#         });
#     </script>

# %%
from pyecharts.charts import WordCloud
from pyecharts import options as opts

wc = WordCloud()
data = [
    ['ThinkPad','15.7'],
    ['联想','14.5'],
    ['惠普','14.4'],
    ['华为','11.7'],
    ['华硕','8.2'],
    ['戴尔','8.1'],
    ['Acer宏碁','4.5'],
    ['苹果','3.5'],
    ['神舟','3.2'],
    ['ROG','3.1'],
    ['机械革命','2.4'],
    ['msi微星','1.8'],
    ['外星人','1.5'],
    ['微软','1.4'],
    ['荣耀','1.2'],
    ['雷神','1'],
    ['三星','0.7'],
    ['红米','0.6'],
    ['机械师','0.5'],
    ['小米','0.5'],
    ['炫龙','0.4'],
    ['雷蛇','0.2'],
    ['壹号本','0.1'],
    ['a豆','0.1'],
    ['未来人类','0.1'],
    ['技嘉','0.1'],
    ['中柏','0.1'],
    ['VAIO','0.1'],
    ['火影','0.1'],
    ['LG','0.1'],
    ['松下','0'],
    ['麦本本','0'],
    ['吾空','0'],
    ['长城','0'],
    ['GPD','0'],
    ['清华同方','0'],
    ['神基','0'],
    ['爱尔轩','0'],
    ['酷比魔方','0'],
    ['海尔','0'],
    ['谷歌','0'],
    ['台电','0'],
    ['iru','0'],
    ['攀升IPASON','0'],
    ['NEC','0'],
    ['夏普','0'],
    ['京东京造','0'],
    ['锡恩帝','0'],
    ['皓勤','0'],
    ['Intel','0'],
]
wc.add('',data)
wc.set_global_opts(title_opts=opts.TitleOpts('词云图'))
wc.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'echarts-wordcloud':'https://assets.pyecharts.org/assets/v5/echarts-wordcloud.min'
#         }
#     });
# </script>
#
#         <div id="5cf140553e564664b8715822979ff82d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'echarts-wordcloud'], function(echarts) {
#                 var chart_5cf140553e564664b8715822979ff82d = echarts.init(
#                     document.getElementById('5cf140553e564664b8715822979ff82d'), 'white', {renderer: 'canvas'});
#                 var option_5cf140553e564664b8715822979ff82d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 12,
#                 60
#             ],
#             "data": [
#                 {
#                     "name": "ThinkPad",
#                     "value": "15.7",
#                     "textStyle": {
#                         "color": "rgb(24,110,134)"
#                     }
#                 },
#                 {
#                     "name": "\u8054\u60f3",
#                     "value": "14.5",
#                     "textStyle": {
#                         "color": "rgb(21,32,11)"
#                     }
#                 },
#                 {
#                     "name": "\u60e0\u666e",
#                     "value": "14.4",
#                     "textStyle": {
#                         "color": "rgb(3,39,34)"
#                     }
#                 },
#                 {
#                     "name": "\u534e\u4e3a",
#                     "value": "11.7",
#                     "textStyle": {
#                         "color": "rgb(41,78,120)"
#                     }
#                 },
#                 {
#                     "name": "\u534e\u7855",
#                     "value": "8.2",
#                     "textStyle": {
#                         "color": "rgb(12,154,54)"
#                     }
#                 },
#                 {
#                     "name": "\u6234\u5c14",
#                     "value": "8.1",
#                     "textStyle": {
#                         "color": "rgb(21,138,78)"
#                     }
#                 },
#                 {
#                     "name": "Acer\u5b8f\u7881",
#                     "value": "4.5",
#                     "textStyle": {
#                         "color": "rgb(85,140,102)"
#                     }
#                 },
#                 {
#                     "name": "\u82f9\u679c",
#                     "value": "3.5",
#                     "textStyle": {
#                         "color": "rgb(60,40,85)"
#                     }
#                 },
#                 {
#                     "name": "\u795e\u821f",
#                     "value": "3.2",
#                     "textStyle": {
#                         "color": "rgb(50,46,140)"
#                     }
#                 },
#                 {
#                     "name": "ROG",
#                     "value": "3.1",
#                     "textStyle": {
#                         "color": "rgb(9,90,143)"
#                     }
#                 },
#                 {
#                     "name": "\u673a\u68b0\u9769\u547d",
#                     "value": "2.4",
#                     "textStyle": {
#                         "color": "rgb(96,114,89)"
#                     }
#                 },
#                 {
#                     "name": "msi\u5fae\u661f",
#                     "value": "1.8",
#                     "textStyle": {
#                         "color": "rgb(99,43,126)"
#                     }
#                 },
#                 {
#                     "name": "\u5916\u661f\u4eba",
#                     "value": "1.5",
#                     "textStyle": {
#                         "color": "rgb(4,31,4)"
#                     }
#                 },
#                 {
#                     "name": "\u5fae\u8f6f",
#                     "value": "1.4",
#                     "textStyle": {
#                         "color": "rgb(79,46,105)"
#                     }
#                 },
#                 {
#                     "name": "\u8363\u8000",
#                     "value": "1.2",
#                     "textStyle": {
#                         "color": "rgb(26,71,36)"
#                     }
#                 },
#                 {
#                     "name": "\u96f7\u795e",
#                     "value": "1",
#                     "textStyle": {
#                         "color": "rgb(48,140,24)"
#                     }
#                 },
#                 {
#                     "name": "\u4e09\u661f",
#                     "value": "0.7",
#                     "textStyle": {
#                         "color": "rgb(74,73,13)"
#                     }
#                 },
#                 {
#                     "name": "\u7ea2\u7c73",
#                     "value": "0.6",
#                     "textStyle": {
#                         "color": "rgb(43,26,10)"
#                     }
#                 },
#                 {
#                     "name": "\u673a\u68b0\u5e08",
#                     "value": "0.5",
#                     "textStyle": {
#                         "color": "rgb(20,143,69)"
#                     }
#                 },
#                 {
#                     "name": "\u5c0f\u7c73",
#                     "value": "0.5",
#                     "textStyle": {
#                         "color": "rgb(85,81,146)"
#                     }
#                 },
#                 {
#                     "name": "\u70ab\u9f99",
#                     "value": "0.4",
#                     "textStyle": {
#                         "color": "rgb(109,94,64)"
#                     }
#                 },
#                 {
#                     "name": "\u96f7\u86c7",
#                     "value": "0.2",
#                     "textStyle": {
#                         "color": "rgb(29,61,134)"
#                     }
#                 },
#                 {
#                     "name": "\u58f9\u53f7\u672c",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(141,33,109)"
#                     }
#                 },
#                 {
#                     "name": "a\u8c46",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(143,117,151)"
#                     }
#                 },
#                 {
#                     "name": "\u672a\u6765\u4eba\u7c7b",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(149,106,57)"
#                     }
#                 },
#                 {
#                     "name": "\u6280\u5609",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(62,72,76)"
#                     }
#                 },
#                 {
#                     "name": "\u4e2d\u67cf",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(33,101,154)"
#                     }
#                 },
#                 {
#                     "name": "VAIO",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(160,6,36)"
#                     }
#                 },
#                 {
#                     "name": "\u706b\u5f71",
#                     "value": "0.1",
#                     "textStyle": {
#                         "color": "rgb(121,102,89)"
#                     }
