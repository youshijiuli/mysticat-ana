# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="Map-基本示例"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="b304bc40edcc4b61a3365f59cc6d172b" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_b304bc40edcc4b61a3365f59cc6d172b = echarts.init(
#                     document.getElementById('b304bc40edcc4b61a3365f59cc6d172b'), 'white', {renderer: 'canvas'});
#                 var option_b304bc40edcc4b61a3365f59cc6d172b = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 115
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 133
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 94
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 130
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 41
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 21
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 29
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Map-\u57fa\u672c\u793a\u4f8b",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_b304bc40edcc4b61a3365f59cc6d172b.setOption(option_b304bc40edcc4b61a3365f59cc6d172b);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.provinces, Faker.values())], "china")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(title_opts=opts.TitleOpts(title="Map-不显示Label"))
    .render_notebook()
)

c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="a305440dbb804dc99ba8229c814312d5" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_a305440dbb804dc99ba8229c814312d5 = echarts.init(
#                     document.getElementById('a305440dbb804dc99ba8229c814312d5'), 'white', {renderer: 'canvas'});
#                 var option_a305440dbb804dc99ba8229c814312d5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 86
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 112
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 99
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 121
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 75
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 142
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 93
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Map-\u4e0d\u663e\u793aLabel",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_a305440dbb804dc99ba8229c814312d5.setOption(option_a305440dbb804dc99ba8229c814312d5);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.guangdong_city, Faker.values())], "广东") # [list(z) for z in zip(['沈阳市'], Faker.values())]
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-广东地图"), visualmap_opts=opts.VisualMapOpts()
    )
        .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="1af671b63c22456ca4931fbcc2c5d1d2" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_1af671b63c22456ca4931fbcc2c5d1d2 = echarts.init(
#                     document.getElementById('1af671b63c22456ca4931fbcc2c5d1d2'), 'white', {renderer: 'canvas'});
#                 var option_1af671b63c22456ca4931fbcc2c5d1d2 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "\u5e7f\u4e1c",
#             "data": [
#                 {
#                     "name": "\u6c55\u5934\u5e02",
#                     "value": 98
#                 },
#                 {
#                     "name": "\u6c55\u5c3e\u5e02",
#                     "value": 33
#                 },
#                 {
#                     "name": "\u63ed\u9633\u5e02",
#                     "value": 50
#                 },
#                 {
#                     "name": "\u9633\u6c5f\u5e02",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u8087\u5e86\u5e02",
#                     "value": 57
#                 },
#                 {
#                     "name": "\u5e7f\u5dde\u5e02",
#                     "value": 108
#                 },
#                 {
#                     "name": "\u60e0\u5dde\u5e02",
#                     "value": 25
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {}
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Map-\u5e7f\u4e1c\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_1af671b63c22456ca4931fbcc2c5d1d2.setOption(option_1af671b63c22456ca4931fbcc2c5d1d2);
#         });
#     </script>

# %%
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker

c = (
    Map()
    .add("商家A", [list(z) for z in zip(Faker.country, Faker.values())], "world")
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Map-世界地图"),
        visualmap_opts=opts.VisualMapOpts(max_=200),
    )
    .render_notebook()
)


c
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'world':'https://assets.pyecharts.org/assets/maps/world'
#         }
#     });
# </script>
#
#         <div id="69e031dcb1424b8588d5d03ef71dd3cd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'world'], function(echarts) {
#                 var chart_69e031dcb1424b8588d5d03ef71dd3cd = echarts.init(
#                     document.getElementById('69e031dcb1424b8588d5d03ef71dd3cd'), 'white', {renderer: 'canvas'});
#                 var option_69e031dcb1424b8588d5d03ef71dd3cd = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u5546\u5bb6A",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": "China",
#                     "value": 63
#                 },
#                 {
#                     "name": "Canada",
#                     "value": 79
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 88
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 116
#                 },
#                 {
#                     "name": "United States",
#                     "value": 95
#                 },
#                 {
#                     "name": "Africa",
#                     "value": 103
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 121
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "title": [
#         {
#             "text": "Map-\u4e16\u754c\u5730\u56fe",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 0,
#         "max": 200,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_69e031dcb1424b8588d5d03ef71dd3cd.setOption(option_69e031dcb1424b8588d5d03ef71dd3cd);
#         });
#     </script>

# %%
#  组合图表 
# 并行多图 Grid()
from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line
from pyecharts.faker import Faker

bar = (
    Bar()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Grid-Bar"))
)
line = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Grid-Line", pos_top="48%"),
        legend_opts=opts.LegendOpts(pos_top="48%"),
    )
)

grid = (
    Grid()
    .add(bar, grid_opts=opts.GridOpts(pos_bottom="60%"))  # 相对于底部高 60 % 
    .add(line, grid_opts=opts.GridOpts(pos_top="60%"))
    .render_notebook()
)

grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="d086ac39910149cfa1019c00cf9ec0a9" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_d086ac39910149cfa1019c00cf9ec0a9 = echarts.init(
#                     document.getElementById('d086ac39910149cfa1019c00cf9ec0a9'), 'white', {renderer: 'canvas'});
#                 var option_d086ac39910149cfa1019c00cf9ec0a9 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 46,
#                 66,
#                 135,
#                 95,
#                 112,
#                 25,
#                 22
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "legendHoverLink": true,
#             "data": [
#                 114,
#                 52,
#                 57,
#                 113,
#                 120,
#                 136,
#                 50
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     23
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     71
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     40
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     24
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     93
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     97
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     121
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u886c\u886b",
#                     77
#                 ],
#                 [
#                     "\u6bdb\u8863",
#                     128
#                 ],
#                 [
#                     "\u9886\u5e26",
#                     20
#                 ],
#                 [
#                     "\u88e4\u5b50",
#                     137
#                 ],
#                 [
#                     "\u98ce\u8863",
#                     150
#                 ],
#                 [
#                     "\u9ad8\u8ddf\u978b",
#                     104
#                 ],
#                 [
#                     "\u889c\u5b50",
#                     117
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "top": "48%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u54c8\u58eb\u5947",
#                 "\u8428\u6469\u8036",
#                 "\u6cf0\u8fea",
#                 "\u91d1\u6bdb",
#                 "\u7267\u7f8a\u72ac",
#                 "\u5409\u5a

# %%
from pyecharts import options as opts
from pyecharts.charts import Grid, Line, Scatter
from pyecharts.faker import Faker

scatter = (
    Scatter()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Grid-Scatter"),
        legend_opts=opts.LegendOpts(pos_left="20%"),
    )
)
line = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(
        title_opts=opts.TitleOpts(title="Grid-Line", pos_right="5%"),
        legend_opts=opts.LegendOpts(pos_right="20%"),
    )
)

grid = (
    Grid()
    .add(scatter, grid_opts=opts.GridOpts(pos_left="55%"))
    .add(line, grid_opts=opts.GridOpts(pos_right="55%"))
    .render_notebook()
)

grid
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f9d322cb7a69417d85be6a6dbabd1888" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f9d322cb7a69417d85be6a6dbabd1888 = echarts.init(
#                     document.getElementById('f9d322cb7a69417d85be6a6dbabd1888'), 'white', {renderer: 'canvas'});
#                 var option_f9d322cb7a69417d85be6a6dbabd1888 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6A",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     45
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     82
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     48
#                 ],
#                 [
#                     "\u5468\u56db",
#                     100
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     26
#                 ],
#                 [
#                     "\u5468\u516d",
#                     115
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     45
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5546\u5bb6B",
#             "xAxisIndex": 0,
#             "yAxisIndex": 0,
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     102
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     45
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     85
#                 ],
#                 [
#                     "\u5468\u56db",
#                     116
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     112
#                 ],
#                 [
#                     "\u5468\u516d",
#                     30
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     56
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     104
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     90
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     122
#                 ],
#                 [
#                     "\u5468\u56db",
#                     34
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     71
#                 ],
#                 [
#                     "\u5468\u516d",
#                     81
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     139
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         },
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6B",
#             "connectNulls": false,
#             "xAxisIndex": 1,
#             "yAxisIndex": 1,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "clip": true,
#             "step": false,
#             "data": [
#                 [
#                     "\u5468\u4e00",
#                     84
#                 ],
#                 [
#                     "\u5468\u4e8c",
#                     55
#                 ],
#                 [
#                     "\u5468\u4e09",
#                     122
#                 ],
#                 [
#                     "\u5468\u56db",
#                     135
#                 ],
#                 [
#                     "\u5468\u4e94",
#                     137
#                 ],
#                 [
#                     "\u5468\u516d",
#                     132
#                 ],
#                 [
#                     "\u5468\u65e5",
#                     45
#                 ]
#             ],
#             "hoverAnimation": true,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "show": true,
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "zlevel": 0,
#             "z": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "left": "20%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         },
#         {
#             "data": [
#                 "\u5546\u5bb6A",
#                 "\u5546\u5bb6B"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true,
#                 "\u5546\u5bb6B": true
#             },
#             "show": true,
#             "right": "20%",
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": tru

# %%
# 选项卡多图 

from pyecharts import options as opts
from pyecharts.charts import Bar, Grid, Line, Pie, Tab
from pyecharts.faker import Faker


def bar_datazoom_slider():
    c = (
        Bar()
        .add_xaxis(Faker.days_attrs)
        .add_yaxis("商家A", Faker.days_values)
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Bar-DataZoom（slider-水平）"),
        )
    )
    return c


def line_markpoint() :
    c = (
        Line()
        .add_xaxis(Faker.choose())
        .add_yaxis(
            "商家A",
            Faker.values(),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Line-MarkPoint"))
    )
    return c


def pie_rosetype():
    v = Faker.choose()
    c = (
        Pie()
        .add(
            "",
            [list(z) for z in zip(v, Faker.values())],
            radius=["30%", "75%"],
            center=["25%", "50%"],
            rosetype="radius",
            label_opts=opts.LabelOpts(is_show=False),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Pie-玫瑰图示例"))
    )
    return c

tab = Tab()
tab.add(bar_datazoom_slider(), "bar-example")
tab.add(line_markpoint(), "line-example")
tab.add(pie_rosetype(), "pie-example")
tab.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <style>
#         .tab {
#             overflow: hidden;
#             border: 1px solid #ccc;
#             background-color: #f1f1f1;
#         }
#
#         .tab button {
#             background-color: inherit;
#             float: left;
#             border: none;
#             outline: none;
#             cursor: pointer;
#             padding: 12px 16px;
#             transition: 0.3s;
#         }
#
#         .tab button:hover {
#             background-color: #ddd;
#         }
#
#         .tab button.active {
#             background-color: #ccc;
#         }
#
#         .chart-container {
#             display: none;
#             padding: 6px 12px;
#             border-top: none;
#         }
#     </style>
# <div class="tab">
#             <button class="tablinks" onclick="showChart(event, '402114a09845428691a7e1d56b0c9ac8')">bar-example</button>
#             <button class="tablinks" onclick="showChart(event, '6a2dc54b52f94aa58b61539576609969')">line-example</button>
#             <button class="tablinks" onclick="showChart(event, '6d79e3d197a84f36bf8e7d29f8423eab')">pie-example</button>
#     </div>
#
#         <div id="402114a09845428691a7e1d56b0c9ac8" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="6a2dc54b52f94aa58b61539576609969" class="chart-container" style="width:900px; height:500px;"></div>
#         <div id="6d79e3d197a84f36bf8e7d29f8423eab" class="chart-container" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_402114a09845428691a7e1d56b0c9ac8 = echarts.init(
#                     document.getElementById('402114a09845428691a7e1d56b0c9ac8'), 'white', {renderer: 'canvas'});
#                 var option_402114a09845428691a7e1d56b0c9ac8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u5546\u5bb6A",
#             "legendHoverLink": true,
#             "data": [
#                 25,
#                 28,
#                 27,
#                 23,
#                 12,
#                 9,
#                 17,
#                 8,
#                 24,
#                 30,
#                 24,
#                 5,
#                 20,
#                 22,
#                 14,
#                 4,
#                 21,
#                 22,
#                 4,
#                 18,
#                 27,
#                 16,
#                 17,
#                 15,
#                 12,
#                 30,
#                 19,
#                 17,
#                 29,
#                 15
#             ],
#             "showBackground": false,
#             "barMinHeight": 0,
#             "barCategoryGap": "20%",
#             "barGap": "30%",
#             "large": false,
#             "largeThreshold": 400,
#             "seriesLayoutBy": "column",
#             "datasetIndex": 0,
#             "clip": true,
#             "zlevel": 0,
#             "z": 2,
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5546\u5bb6A"
#             ],
#             "selected": {
#                 "\u5546\u5bb6A": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "0\u5929",
#                 "1\u5929",
#                 "2\u5929",
#                 "3\u5929",
#                 "4\u5929",
#                 "5\u5929",
#                 "6\u5929",
#                 "7\u5929",
#                 "8\u5929",
#                 "9\u5929",
#                 "10\u5929",
#                 "11\u5929",
#                 "12\u5929",
#                 "13\u5929",
#                 "14\u5929",
#                 "15\u5929",
#                 "16\u5929",
#                 "17\u5929",
#                 "18\u5929",
#                 "19\u5929",
#                 "20\u5929",
#                 "21\u5929",
#                 "22\u5929",
#                 "23\u5929",
#                 "24\u5929",
#                 "25\u5929",
#                 "26\u5929",
#                 "27\u5929",
#                 "28\u5929",
#                 "29\u5929"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "show": true,
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {
#             "text": "Bar-DataZoom\uff08slider-\u6c34\u5e73\uff09",
#             "padding": 5,
#             "itemGap": 10
#         }
#     ]
# };
#                 chart_402114a09845428691a7e1d56b0c9ac8.setOption(option_402114a09845428691a7e1d56b0c9ac8);
#                 var chart_6a2dc54b52f94aa58b61539576609969 = echarts.init(
#                     document.getElementById('6a2dc54b52f94aa58b61539576609969'), 'white', {renderer: 'canvas'});
#                 var option_6a2dc54b52f94aa58b61539576609969 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5546\u5bb6A",
#             "connectNu
